# %% [markdown]
# # Accuracy Measurements for Object Detection and Tracking with YOLOv8, ByteTrack, and the VIRAT Dataset

# %% [markdown]
# ## 1. Data Import
# ## 2.

# %% [markdown]
# ## 1. Data Import
# - obtain sample video from dataset for inference

# %%
import pandas as pd
import torch

# %%
# upload sample file: 'VIRAT_S_000200_03_000657_000899_first300.mp4'
# this is the first 300 frames of 'VIRAT_S_000200_03_000657_000899.mp4'

# !gdown "https://drive.google.com/uc?id=1C-HPOEIdZnJm_RSbYGXH6gMLhlmobaxn" -O test.mp4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1C-HPOEIdZnJm_RSbYGXH6gMLhlmobaxn
# To: /content/test.mp4
# 100% 10.4M/10.4M [00:00<00:00, 52.9MB/s]

# %% [markdown]
# I used `ffmpeg -i VIRAT_S_000200_03_000657_000899.mp4 -c:v copy -frames:v 300 -r 30 -an ~/Desktop/VIRAT_S_000200_03_000657_000899_first300.mp4
# `

# %%
# display details of clip
# !ffprobe -v quiet -print_format json -show_format -show_streams test.mp4
# Out:
# {
#     "streams": [
#         {
#             "index": 0,
#             "codec_name": "mpeg4",
#             "codec_long_name": "MPEG-4 part 2",
#             "profile": "Simple Profile",
#             "codec_type": "video",
#             "codec_time_base": "1/30",
#             "codec_tag_string": "mp4v",
#             "codec_tag": "0x7634706d",
#             "width": 1280,
#             "height": 720,
#             "coded_width": 1280,
#             "coded_height": 720,
#             "has_b_frames": 0,
#             "sample_aspect_ratio": "1:1",
#             "display_aspect_ratio": "16:9",
#             "pix_fmt": "yuv420p",
#             "level": 3,
#             "color_range": "tv",
#             "color_space": "bt709",
#             "color_transfer": "bt709",
#             "color_primaries": "bt709",
#             "chroma_location": "left",
#             "refs": 1,
#             "quarter_sample": "false",
#             "divx_packed": "false",
#             "r_frame_rate": "30/1",
#             "avg_frame_rate": "30/1",
#             "time_base": "1/11988",
#             "start_pts": 0,
#             "start_time": "0.000000",
#             "duration_ts": 119880,
#             "duration": "10.000000",
#             "bit_rate": "8320345",
#             "max_bit_rate": "8320345",
#             "nb_frames": "300",
#             "disposition": {
#                 "default": 1,
#                 "dub": 0,
#                 "original": 0,
#                 "comment": 0,
#                 "lyrics": 0,
#                 "karaoke": 0,
#                 "forced": 0,
#                 "hearing_impaired": 0,
#                 "visual_impaired": 0,
#                 "clean_effects": 0,
#                 "attached_pic": 0,
#                 "timed_thumbnails": 0
#             },
#             "tags": {
#                 "language": "und",
#                 "handler_name": "VideoHandler"
#             }
#         }
#     ],
#     "format": {
#         "filename": "test.mp4",
#         "nb_streams": 1,
#         "nb_programs": 0,
#         "format_name": "mov,mp4,m4a,3gp,3g2,mj2",
#         "format_long_name": "QuickTime / MOV",
#         "start_time": "0.000000",
#         "duration": "10.000000",
#         "size": "10404719",
#         "bit_rate": "8323775",
#         "probe_score": 100,
#         "tags": {
#             "major_brand": "isom",
#             "minor_version": "512",
#             "compatible_brands": "isomiso2mp41",
#             "encoder": "Lavf60.3.100"
#         }
#     }
# }

# %%
# !ls -lh
# Out:
# total 10M
# drwxr-xr-x 1 root root 4.0K Jun 23 01:15 sample_data
# -rw-r--r-- 1 root root  10M Jun 23 18:46 test.mp4

# %% [markdown]
# ## 2. Ground Truth
# - obtain the ground truth bounding boxes data
# - store in Pandas DataFrame 'gtdf'

# %%
# VIRAT_S_000200_03_000657_000899.types.yml
# !gdown "https://drive.google.com/uc?id=12h_35hXzoSciduBzDWmpKB2-rgUuraiN" -O test.types.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12h_35hXzoSciduBzDWmpKB2-rgUuraiN
# To: /content/test.types.yml
# 100% 2.71k/2.71k [00:00<00:00, 19.3MB/s]

# %%
# VIRAT_S_000200_03_000657_000899.regions.yml
# !gdown "https://drive.google.com/uc?id=1Ieau47ZxLLpE6mw04XwjfANeQPB9m7hY" -O test.regions.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ieau47ZxLLpE6mw04XwjfANeQPB9m7hY
# To: /content/test.regions.yml
# 100% 12.6M/12.6M [00:00<00:00, 142MB/s]

# %%
# VIRAT_S_000200_03_000657_000899.geom.yml
# !gdown "https://drive.google.com/uc?id=1UH9s2MPSZFdJJ7TD827DrmqGPtR_CWdQ" -O test.geom.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UH9s2MPSZFdJJ7TD827DrmqGPtR_CWdQ
# To: /content/test.geom.yml
# 100% 8.54M/8.54M [00:00<00:00, 84.5MB/s]

# %%
# VIRAT_S_000200_03_000657_000899.activities.yml
# !gdown "https://drive.google.com/uc?id=1tTAnWLE5f9FhbWCe4vElR7gD9aK0jYin" -O test.activities.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tTAnWLE5f9FhbWCe4vElR7gD9aK0jYin
# To: /content/test.activities.yml
# 100% 14.3k/14.3k [00:00<00:00, 61.0MB/s]

# %%
# !ls -lh
# Out:
# total 31M
# drwxr-xr-x 1 root root 4.0K Jun 23 01:15 sample_data
# -rw-r--r-- 1 root root  14K Jun 23 18:46 test.activities.yml
# -rw-r--r-- 1 root root 8.2M Jun 23 18:46 test.geom.yml
# -rw-r--r-- 1 root root  10M Jun 23 18:46 test.mp4
# -rw-r--r-- 1 root root  12M Jun 23 18:46 test.regions.yml
# -rw-r--r-- 1 root root 2.7K Jun 23 18:46 test.types.yml

# %%
# get bounding boxes, classes and track ids for detections in the first frame
import yaml

file_path = 'test.geom.yml'
with open(file_path, 'r') as file:
    geom = yaml.safe_load(file)
file_path = 'test.types.yml'
with open(file_path, 'r') as file:
    types = yaml.safe_load(file)

# %% [markdown]
# ### Create Ground Truth DataFrame

# %% [markdown]
# AS pd.DataFrame </br>
# format: </br>
# {idx: geom_id0, </br>
# track_id: geom_id1, </br>
# label: types_cset3-key_on_id1, </br>
# conf: types_cset3-value_on_id1, </br>
# frame: geom_ts0, </br>
# xmin: geom_g0.split(' ')[0], ymin: geom_g0.split(' ')[1], xmax: geom_g0.split(' ')[2], ymax: geom_g0.split(' ')[3]}

# %%
# helper function to get gt labels and confidence from types

def get_labels_conf(types, frame_num):
  # returns lists: labels, conf
  labels = []
  conf = []
  for i in types:
    try:
      if (i['types']['id1'] in track_id):
          label, conf = next(iter(i['types']['cset3'].items()))
          labels.append(label)
          conf.appens(conf)
    except:
      pass

  return labels, conf


# helper function to get labels as integers. Only working for 'Person', 'Bike' and 'Vehicle' currently [0,1,2]
def labels_as_int(label):
  labels = []
  for i in range(len(label)):
    if label[i] == 'Person':
      labels.append(0)
    elif label[i] == 'Bike':
      labels.append(1)
    elif label[i] == 'Vehicle':
      labels.append(2)
    else:
      labels.append(-1)
  return labels

# %%
# create a ground truth dataframe, gtdf

detections = []
frame_num = 0

# sample of geom with detections by frame_num
for i in geom:
  try:
    if (i['geom']['ts0'] == frame_num):
      detections.append(i)
  except:
    pass

# parse data from detections
idx = [i['geom']['id0'] for i in detections]
track_id = [i['geom']['id1'] for i in detections]
label, conf = get_labels_conf(types, frame_num)
frame = [i['geom']['ts0'] for i in detections]
xmin, ymin, xmax, ymax = [], [], [], []
for i in detections:
  bb = i['geom']['g0'].split(' ')
  xmin.append(int(bb[0]))
  ymin.append(int(bb[1]))
  xmax.append(int(bb[2]))
  ymax.append(int(bb[3]))

# get class labels as int for comparison with predictions
label_int = labels_as_int(label)

gt = {'idx_gt': idx, 'track_id_gt': track_id, 'label_gt': label,
      'label_as_int_gt': label_int, 'conf_gt': conf, 'frame_gt': frame,
      'xmin_gt': xmin, 'ymin_gt': ymin, 'xmax_gt': xmax, 'ymax_gt': ymax}
gtdf = pd.DataFrame(gt)
gtdf
# Out:
#     idx_gt  track_id_gt       label_gt  label_as_int_gt  conf_gt  frame_gt  \
# 0        0            1        Vehicle                2      1.0         0
# 1     7243            2        Vehicle                2      1.0         0
# 2    14486            3        Vehicle                2      1.0         0
# 3    21729            4        Vehicle                2      1.0         0
# 4    28972            5        Vehicle                2      1.0         0
# 5    34911           33         Person                0      1.0         0
# 6    39594           34         Person                0      1.0         0
# 7    46239           35         Person                0      1.0         0
# 8    51025         5000  Parking_Meter               -1      1.0         0
# 9    58268         5001       Dumpster               -1      1.0         0
# 10   65511         5025           Tree               -1      1.0         0
# 11   72754         5030           Door               -1      1.0         0
#
#     xmin_gt  ymin_gt  xmax_gt  ymax_gt
# 0       946      327     1010      360
# 1       648      495      801      559
# 2       114      375      237      419
# 3       102      349      212      386
# 4       902      659     1023      718
# 5       281      517      320      577
# 6       730      392      756      437
# 7      1149      644     1185      714
# 8      1056      368     1070      402
# 9        69      291      117      328
# 10        0      470      226      719
# 11       72      423       95      487

# %%
gtdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idx_gt           12 non-null     int64
#  1   track_id_gt      12 non-null     int64
#  2   label_gt         12 non-null     object
#  3   label_as_int_gt  12 non-null     int64
#  4   conf_gt          12 non-null     float64
#  5   frame_gt         12 non-null     int64
#  6   xmin_gt          12 non-null     int64
#  7   ymin_gt          12 non-null     int64
#  8   xmax_gt          12 non-null     int64
#  9   ymax_gt          12 non-null     int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# ## 3. Get Predictions
# - get inference from YOLOv8 with ByteTracker on this test clip
# - store predictions in Pandas DataFrame 'preddf'

# %% [markdown]
# Install YOLOv8

# %%
# !pip -q install ultralytics
# !pip -q install lap
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lap (setup.py) ... done

# %%
from ultralytics import YOLO
import lap

model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 74.7MB/s]

# %%
results = model.track(source='/content/test.mp4', conf=0.12, iou=0.5,
                      device=0, save_txt=True, imgsz=1280, classes=[0,1,2],
                      tracker="bytetrack.yaml", stream=True)
list_results = list(results)
# Out:
# video 1/1 (1/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 71.6ms
# video 1/1 (2/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (3/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (4/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (5/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (6/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (7/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (8/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 14.7ms
# video 1/1 (9/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 40.6ms
# video 1/1 (10/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 37.9ms
# video 1/1 (11/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (12/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (13/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 15.1ms
# video 1/1 (14/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (15/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 17.4ms
# video 1/1 (16/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 34.5ms
# video 1/1 (17/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 21.9ms
# video 1/1 (18/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (19/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (20/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (21/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 26.2ms
# video 1/1 (22/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 24.6ms
# video 1/1 (23/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 26.0ms
# video 1/1 (24/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 14.0ms
# video 1/1 (25/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (26/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.5ms
# video 1/1 (27/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (28/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (29/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.3ms
# video 1/1 (30/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.3ms
# video 1/1 (31/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (32/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.3ms
# video 1/1 (33/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.3ms
# video 1/1 (34/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.5ms
# video 1/1 (35/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (36/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (37/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (38/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (39/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (40/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (41/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (42/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.1ms
# video 1/1 (43/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.5ms
# video 1/1 (44/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.5ms
# video 1/1 (45/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.5ms
# video 1/1 (46/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.8ms
# video 1/1 (47/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.5ms
# video 1/1 (48/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.9ms
# video 1/1 (49/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.5ms
# video 1/1 (50/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (51/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.7ms
# video 1/1 (52/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (53/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (54/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (55/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (56/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (57/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (58/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.6ms
# video 1/1 (59/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.7ms
# video 1/1 (60/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (61/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.6ms
# video 1/1 (62/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.7ms
# video 1/1 (63/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.7ms
# video 1/1 (64/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.7ms
# video 1/1 (65/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (66/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (67/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (68/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (69/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (70/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (71/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (72/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.5ms
# video 1/1 (73/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.5ms
# video 1/1 (74/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (75/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.4ms
# video 1/1 (76/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (77/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (78/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (79/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (80/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (81/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (82/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (83/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 15.0ms
# video 1/1 (84/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (85/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (86/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (87/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (88/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (89/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (90/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.5ms
# video 1/1 (91/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.4ms
# video 1/1 (92/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (93/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (94/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (95/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (96/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (97/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.3ms
# video 1/1 (98/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 8.9ms
# video 1/1 (99/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 8.8ms
# video 1/1 (100/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (101/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (102/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (103/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.9ms
# video 1/1 (104/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (105/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.9ms
# video 1/1 (106/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (107/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (108/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (109/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (110/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (111/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (112/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (113/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (114/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.0ms
# video 1/1 (115/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (116/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (117/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (118/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (119/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.9ms
# video 1/1 (120/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (121/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.9ms
# video 1/1 (122/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (123/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (124/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.4ms
# video 1/1 (125/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.7ms
# video 1/1 (126/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (127/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (128/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (129/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 13.6ms
# video 1/1 (130/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (131/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (132/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (133/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (134/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (135/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (136/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.2ms
# video 1/1 (137/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (138/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (139/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (140/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (141/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (142/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (143/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.9ms
# video 1/1 (144/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (145/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (146/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.0ms
# video 1/1 (147/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (148/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (149/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (150/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (151/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (152/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (153/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.9ms
# video 1/1 (154/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (155/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (156/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (157/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (158/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (159/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (160/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (161/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (162/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (163/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.7ms
# video 1/1 (164/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (165/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (166/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (167/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (168/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.3ms
# video 1/1 (169/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (170/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 14.6ms
# video 1/1 (171/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (172/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (173/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (174/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (175/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (176/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (177/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (178/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (179/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (180/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.8ms
# video 1/1 (181/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (182/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (183/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 8.7ms
# video 1/1 (184/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (185/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (186/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (187/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (188/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (189/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (190/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (191/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (192/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 12.0ms
# video 1/1 (193/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (194/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (195/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (196/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.3ms
# video 1/1 (197/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (198/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (199/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.7ms
# video 1/1 (200/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.1ms
# video 1/1 (201/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (202/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.3ms
# video 1/1 (203/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 13.3ms
# video 1/1 (204/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (205/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (206/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.4ms
# video 1/1 (207/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (208/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (209/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (210/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (211/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (212/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (213/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (214/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.3ms
# video 1/1 (215/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.3ms
# video 1/1 (216/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.6ms
# video 1/1 (217/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.6ms
# video 1/1 (218/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (219/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (220/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (221/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (222/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (223/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (224/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (225/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (226/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (227/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (228/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (229/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (230/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (231/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (232/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (233/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (234/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (235/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (236/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (237/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (238/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (239/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (240/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (241/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (242/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (243/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (244/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (245/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (246/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (247/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (248/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (249/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (250/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (251/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (252/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.6ms
# video 1/1 (253/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (254/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (255/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (256/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (257/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (258/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.4ms
# video 1/1 (259/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (260/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (261/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (262/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (263/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (264/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (265/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (266/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (267/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (268/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (269/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.3ms
# video 1/1 (270/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (271/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (272/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (273/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (274/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (275/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (276/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (277/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (278/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (279/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (280/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (281/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (282/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (283/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (284/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (285/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (286/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (287/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.1ms
# video 1/1 (288/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.1ms
# video 1/1 (289/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.1ms
# video 1/1 (290/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.1ms
# video 1/1 (291/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.1ms
# video 1/1 (292/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.1ms
# video 1/1 (293/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.1ms
# video 1/1 (294/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (295/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.0ms
# video 1/1 (296/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (297/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.0ms
# video 1/1 (298/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.0ms
# video 1/1 (299/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.0ms
# video 1/1 (300/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.0ms
# Speed: 5.2ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/track
# 300 labels saved to runs/detect/track/labels

# %%
# frame 1 detections as .txt file(s)
# !cat runs/detect/track/labels/test_1.txt
# Out:
# 2 0.137419 0.553092 0.0945308 0.0548357 1
# 2 0.763876 0.478838 0.0469688 0.0366087 2
# 2 0.123751 0.511463 0.0826546 0.044233 3
# 2 0.567661 0.733765 0.111929 0.0792986 4
# 0 0.232489 0.761387 0.019395 0.080564 5
# 0 0.581185 0.575837 0.0138645 0.05707 6
# 2 0.751597 0.962718 0.090546 0.0741219 7
# 0 0.909582 0.944357 0.0208885 0.095949 8

# %% [markdown]
# .txt files format ^
# - [class, xmid, ymid, w, h, track_id]</br></br>

# %%
# frame 1 detection as tensor objects
list_results[0].boxes
# Out:
# WARNING ⚠️ 'Boxes.boxes' is deprecated. Use 'Boxes.data' instead.
# ultralytics.yolo.engine.results.Boxes object with attributes:
#
# boxes: tensor([[1.1540e+02, 3.7849e+02, 2.3640e+02, 4.1797e+02, 1.0000e+00, 8.8784e-01, 2.0000e+00],
#         [9.4770e+02, 3.3158e+02, 1.0078e+03, 3.5794e+02, 2.0000e+00, 8.5510e-01, 2.0000e+00],
#         [1.0550e+02, 3.5233e+02, 2.1130e+02, 3.8418e+02, 3.0000e+00, 8.5349e-01, 2.0000e+00],
#         [6.5497e+02, 4.9976e+02, 7.9824e+02, 5.5686e+02, 4.0000e+00, 8.5208e-01, 2.0000e+00],
#         [2.8517e+02, 5.1920e+02, 3.1000e+02, 5.7720e+02, 5.0000e+00, 8.3465e-01, 0.0000e+00],
#         [7.3504e+02, 3.9406e+02, 7.5279e+02, 4.3515e+02, 6.0000e+00, 7.6037e-01, 0.0000e+00],
#         [9.0410e+02, 6.6647e+02, 1.0200e+03, 7.1984e+02, 7.0000e+00, 7.5590e-01, 2.0000e+00],
#         [1.1509e+03, 6.4540e+02, 1.1776e+03, 7.1448e+02, 8.0000e+00, 6.6577e-01, 0.0000e+00]])
# cls: tensor([2., 2., 2., 2., 0., 0., 2., 0.])
# conf: tensor([0.8878, 0.8551, 0.8535, 0.8521, 0.8347, 0.7604, 0.7559, 0.6658])
# data: tensor([[1.1540e+02, 3.7849e+02, 2.3640e+02, 4.1797e+02, 1.0000e+00, 8.8784e-01, 2.0000e+00],
#         [9.4770e+02, 3.3158e+02, 1.0078e+03, 3.5794e+02, 2.0000e+00, 8.5510e-01, 2.0000e+00],
#         [1.0550e+02, 3.5233e+02, 2.1130e+02, 3.8418e+02, 3.0000e+00, 8.5349e-01, 2.0000e+00],
#         [6.5497e+02, 4.9976e+02, 7.9824e+02, 5.5686e+02, 4.0000e+00, 8.5208e-01, 2.0000e+00],
#         [2.8517e+02, 5.1920e+02, 3.1000e+02, 5.7720e+02, 5.0000e+00, 8.3465e-01, 0.0000e+00],
#         [7.3504e+02, 3.9406e+02, 7.5279e+02, 4.3515e+02, 6.0000e+00, 7.6037e-01, 0.0000e+00],
#         [9.0410e+02, 6.6647e+02, 1.0200e+03, 7.1984e+02, 7.0000e+00, 7.5590e-01, 2.0000e+00],
#         [1.1509e+03, 6.4540e+02, 1.1776e+03, 7.1448e+02, 8.0000e+00, 6.6577e-01, 0.0000e+00]])
# id: tensor([1., 2., 3., 4., 5., 6., 7., 8.])
# is_track: True
# orig_shape: (720, 1280)
# shape: torch.Size([8, 7])
# xywh: tensor([[ 175.8964,  398.2260,  120.9994,   39.4817],
#         [ 977.7612,  344.7637,   60.1201,   26.3583],
#         [ 158.4019,  368.2531,  105.7979,   31.8478],
#         [ 726.6056,  528.3107,  143.2695,   57.0950],
#         [ 297.5856,  548.1984,   24.8256,   58.0061],
#         [ 743.9169,  414.6028,   17.7466,   41.0904],
#         [ 962.0447,  693.1568,  115.8989,   53.3678],
#         [1164.2654,  679.9373,   26.7373,   69.0833]])
# xywhn: tensor([[0.1374, 0.5531, 0.0945, 0.0548],
#         [0.7639, 0.4788, 0.0470, 0.0366],
#         [0.1238, 0.5115, 0.0827, 0.0442],
#         [0.5677, 0.7338, 0.1119, 0.0793],
#         [0.2325, 0.7614, 0.0194, 0.0806],
#         [0.5812, 0.5758, 0.0139, 0.0571],
#         [0.7516, 0.9627, 0.0905, 0.0741],
#         [0.9096, 0.9444, 0.0209, 0.0959]])
# xyxy: tensor([[ 115.3967,  378.4852,  236.3961,  417.9669],
#         [ 947.7012,  331.5845, 1007.8213,  357.9428],
#         [ 105.5029,  352.3292,  211.3009,  384.1770],
#         [ 654.9708,  499.7632,  798.2404,  556.8582],
#         [ 285.1728,  519.1953,  309.9984,  577.2014],
#         [ 735.0436,  394.0576,  752.7902,  435.1480],
#         [ 904.0953,  666.4729, 1019.9942,  719.8407],
#         [1150.8967,  645.3957, 1177.6340,  714.4789]])
# xyxyn: tensor([[0.0902, 0.5257, 0.1847, 0.5805],
#         [0.7404, 0.4605, 0.7874, 0.4971],
#         [0.0824, 0.4893, 0.1651, 0.5336],
#         [0.5117, 0.6941, 0.6236, 0.7734],
#         [0.2228, 0.7211, 0.2422, 0.8017],
#         [0.5743, 0.5473, 0.5881, 0.6044],
#         [0.7063, 0.9257, 0.7969, 0.9998],
#         [0.8991, 0.8964, 0.9200, 0.9923]])

# %% [markdown]
# ultralytics.yolo.engine.results.Boxes attribute formats ^:
# - Boxes.boxes, Boxes.data use [xmin, ymin, xmax, ymax, track_id, conf, class]
# - xywh, xywhn use [xmid, ymid, w, h]
# - xyxy, xyxyn use [xmin, ymin, xmax, ymax]

# %%
list_results[0].boxes.data[0][6]
# Out:
# tensor(2.)

# %% [markdown]
# ### Create DataFrame for predictions

# %%
# Create dictionary of predictions

frame_num = 0

track_id = []
label = []
conf = []
frame = []
xmin, ymin, xmax, ymax = [], [], [], []

for i in range(len(list_results[frame_num].boxes.data)):
  bb = [torch.round(j) for j in iter(list_results[frame_num].boxes.data[i])]
  track_id.append(int(bb[4]))
  label.append(int(bb[6]))
  conf.append(int(bb[5]))
  frame.append(frame_num)
  xmin.append(int(bb[0]))
  ymin.append(int(bb[1]))
  xmax.append(int(bb[2]))
  ymax.append(int(bb[3]))

pred = {'track_id': track_id, 'label': label, 'conf': conf, 'frame': frame, 'xmin': xmin, 'ymin': ymin, 'xmax': xmax, 'ymax': ymax}

preddf = pd.DataFrame(pred)

# %%
preddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   track_id  8 non-null      int64
#  1   label     8 non-null      int64
#  2   conf      8 non-null      int64
#  3   frame     8 non-null      int64
#  4   xmin      8 non-null      int64
#  5   ymin      8 non-null      int64
#  6   xmax      8 non-null      int64
#  7   ymax      8 non-null      int64
# dtypes: int64(8)
# memory usage: 640.0 bytes

# %%
preddf
# Out:
#    track_id  label  conf  frame  xmin  ymin  xmax  ymax
# 0         1      2     1      0   115   378   236   418
# 1         2      2     1      0   948   332  1008   358
# 2         3      2     1      0   106   352   211   384
# 3         4      2     1      0   655   500   798   557
# 4         5      0     1      0   285   519   310   577
# 5         6      0     1      0   735   394   753   435
# 6         7      2     1      0   904   666  1020   720
# 7         8      0     1      0  1151   645  1178   714

# %% [markdown]
# ## 4. Calculate IOU

# %%
import numpy as np

def get_iou(boxA, boxB):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.

    Parameters:
    boxA -- [xmin, ymin, xmax, ymax] of box A
    boxB -- [xmin, ymin, xmax, ymax] of box B

    Returns:
    iou   -- Intersection over Union
    """
    # determine the (x, y)-coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)

    # compute the area of both the prediction and ground-truth rectangles
    boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
    boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)

    # compute the intersection over union by taking the intersection area and dividing it by the sum of prediction + ground-truth areas - the intersection area
    iou = interArea / float(boxAArea + boxBArea - interArea)

    # return the intersection over union value
    return iou

# %%
# Create a cross join dataframe
gtdf['key'] = 1
preddf['key'] = 1
df_cross = pd.merge(gtdf, preddf, on ='key').drop("key", axis=1)

# %%
# Calculate IOU for each pair
df_cross['iou'] = df_cross.apply(lambda row: get_iou(row[['xmin_gt', 'ymin_gt', 'xmax_gt', 'ymax_gt']], row[['xmin', 'ymin', 'xmax', 'ymax']]), axis=1)

# Find the pairs with maximum IOU for each ground truth bounding box
df_matched = df_cross.loc[df_cross.groupby(['idx_gt'])['iou'].idxmax()]

# Drop any unmatched predictions
df_matched = df_matched[df_matched['iou'] > 0]
df_matched
# Out:
#     idx_gt  track_id_gt label_gt  label_as_int_gt  conf_gt  frame_gt  xmin_gt  \
# 1        0            1  Vehicle                2      1.0         0      946
# 11    7243            2  Vehicle                2      1.0         0      648
# 16   14486            3  Vehicle                2      1.0         0      114
# 26   21729            4  Vehicle                2      1.0         0      102
# 38   28972            5  Vehicle                2      1.0         0      902
# 44   34911           33   Person                0      1.0         0      281
# 53   39594           34   Person                0      1.0         0      730
# 63   46239           35   Person                0      1.0         0     1149
#
#     ymin_gt  xmax_gt  ymax_gt  track_id  label  conf  frame  xmin  ymin  xmax  \
# 1       327     1010      360         2      2     1      0   948   332  1008
# 11      495      801      559         4      2     1      0   655   500   798
# 16      375      237      419         1      2     1      0   115   378   236
# 26      349      212      386         3      2     1      0   106   352   211
# 38      659     1023      718         7      2     1      0   904   666  1020
# 44      517      320      577         5      0     1      0   285   519   310
# 53      392      756      437         6      0     1      0   735   394   753
# 63      644     1185      714         8      0     1      0  1151   645  1178
#
#     ymax       iou
# 1    358  0.745249
# 11   557  0.834366
# 16   418  0.896416
# 26   384  0.829303
# 38   720  0.820890
# 44   577  0.628689
# 53   435  0.642512
# 63   714  0.746098
