# %% [markdown]
# ### Model Deployment

# %% [markdown]
# Network Traffic
# - To ensure online security, everything should run through SSL and HTTPS
# - The current deployment architecture:
#     - App is hosted on EC2 instance at http://ec2-18-144-34-247.us-west-1.compute.amazonaws.com
#     - Personal website has an `<iframe>` which will display the pages of the app
#     - nginx is used as a reverse proxy in front of gunicorn
#     - gunicorn is used to allow multithreading and multiple network requests at once

# %%
# display of app in personal website
image_path = '/Users/p/Documents/Code/personal-website-2023-08/success-2023-08-14/larger image iframe success incognito only.png'
display(Image(image_path))

# %% [markdown]
# AWS EC2, ECR, and ECS
# - App is hosted on an EC2 instance. It runs as a docker container (image below).
# - ECR and ECS will be used to automate resource requirements as the app is used.

# %%
image_path = '/Users/p/Documents/Code/VIRAT/VIRAT_Ground_Dataset/images/App_Dockerfile.png'
display(Image(image_path))

# %% [markdown]
# ### Data Storage

# %% [markdown]
# - The Detections Data (the pandas dataframe from our helper class) are stored in an S3 bucket
# - The images are written to an S3 bucket
# - Analytics and a list of detections are returned to the user
