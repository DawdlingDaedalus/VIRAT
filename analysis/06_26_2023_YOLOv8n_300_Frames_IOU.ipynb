# %% [markdown]
# # YOLOv8n Model
# # ("n" nano: smallest, quickest, but lowest accuracy)
# ## Inference and IOU Score on 300 frames of VIRAT Ground Video
# - 5 Vehicles
# - 3 Persons

# %% [markdown]
# ## 1. Data Import

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import pandas as pd
import numpy as np
import torch

# %%
# upload sample file: 'VIRAT_S_000200_03_000657_000899_first300.mp4'
# this is the first 300 frames of 'VIRAT_S_000200_03_000657_000899.mp4'
# viewable at: https://drive.google.com/file/d/1C-HPOEIdZnJm_RSbYGXH6gMLhlmobaxn/view?usp=drive_link

# !gdown "https://drive.google.com/uc?id=1C-HPOEIdZnJm_RSbYGXH6gMLhlmobaxn" -O test.mp4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1C-HPOEIdZnJm_RSbYGXH6gMLhlmobaxn
# To: /content/test.mp4
# 100% 10.4M/10.4M [00:00<00:00, 144MB/s]

# %% [markdown]
# I used `ffmpeg -i VIRAT_S_000200_03_000657_000899.mp4 -c:v copy -frames:v 300 -r 30 -an ~/Desktop/VIRAT_S_000200_03_000657_000899_first300.mp4` to create cut the first 300 frames of this video to a clip

# %%
# display details of clip
# !ffprobe -v quiet -print_format json -show_format -show_streams test.mp4
# Out:
# {
#     "streams": [
#         {
#             "index": 0,
#             "codec_name": "mpeg4",
#             "codec_long_name": "MPEG-4 part 2",
#             "profile": "Simple Profile",
#             "codec_type": "video",
#             "codec_time_base": "1/30",
#             "codec_tag_string": "mp4v",
#             "codec_tag": "0x7634706d",
#             "width": 1280,
#             "height": 720,
#             "coded_width": 1280,
#             "coded_height": 720,
#             "has_b_frames": 0,
#             "sample_aspect_ratio": "1:1",
#             "display_aspect_ratio": "16:9",
#             "pix_fmt": "yuv420p",
#             "level": 3,
#             "color_range": "tv",
#             "color_space": "bt709",
#             "color_transfer": "bt709",
#             "color_primaries": "bt709",
#             "chroma_location": "left",
#             "refs": 1,
#             "quarter_sample": "false",
#             "divx_packed": "false",
#             "r_frame_rate": "30/1",
#             "avg_frame_rate": "30/1",
#             "time_base": "1/11988",
#             "start_pts": 0,
#             "start_time": "0.000000",
#             "duration_ts": 119880,
#             "duration": "10.000000",
#             "bit_rate": "8320345",
#             "max_bit_rate": "8320345",
#             "nb_frames": "300",
#             "disposition": {
#                 "default": 1,
#                 "dub": 0,
#                 "original": 0,
#                 "comment": 0,
#                 "lyrics": 0,
#                 "karaoke": 0,
#                 "forced": 0,
#                 "hearing_impaired": 0,
#                 "visual_impaired": 0,
#                 "clean_effects": 0,
#                 "attached_pic": 0,
#                 "timed_thumbnails": 0
#             },
#             "tags": {
#                 "language": "und",
#                 "handler_name": "VideoHandler"
#             }
#         }
#     ],
#     "format": {
#         "filename": "test.mp4",
#         "nb_streams": 1,
#         "nb_programs": 0,
#         "format_name": "mov,mp4,m4a,3gp,3g2,mj2",
#         "format_long_name": "QuickTime / MOV",
#         "start_time": "0.000000",
#         "duration": "10.000000",
#         "size": "10404719",
#         "bit_rate": "8323775",
#         "probe_score": 100,
#         "tags": {
#             "major_brand": "isom",
#             "minor_version": "512",
#             "compatible_brands": "isomiso2mp41",
#             "encoder": "Lavf60.3.100"
#         }
#     }
# }

# %%
# !ls -lh
# Out:
# total 10M
# drwxr-xr-x 1 root root 4.0K Jun 26 13:35 sample_data
# -rw-r--r-- 1 root root  10M Jun 27 18:21 test.mp4

# %% [markdown]
# ## 2. Ground Truth

# %% [markdown]
# - Data from https://gitlab.kitware.com/viratdata/viratannotations
# - obtain the ground truth bounding boxes data
# - store in Pandas DataFrame 'gtdf'

# %%
# VIRAT_S_000200_03_000657_000899.types.yml
# !gdown "https://drive.google.com/uc?id=12h_35hXzoSciduBzDWmpKB2-rgUuraiN" -O test.types.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12h_35hXzoSciduBzDWmpKB2-rgUuraiN
# To: /content/test.types.yml
# 100% 2.71k/2.71k [00:00<00:00, 15.4MB/s]

# %%
# VIRAT_S_000200_03_000657_000899.regions.yml
# !gdown "https://drive.google.com/uc?id=1Ieau47ZxLLpE6mw04XwjfANeQPB9m7hY" -O test.regions.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ieau47ZxLLpE6mw04XwjfANeQPB9m7hY
# To: /content/test.regions.yml
# 100% 12.6M/12.6M [00:00<00:00, 194MB/s]

# %%
# VIRAT_S_000200_03_000657_000899.geom.yml
# !gdown "https://drive.google.com/uc?id=1UH9s2MPSZFdJJ7TD827DrmqGPtR_CWdQ" -O test.geom.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UH9s2MPSZFdJJ7TD827DrmqGPtR_CWdQ
# To: /content/test.geom.yml
# 100% 8.54M/8.54M [00:00<00:00, 110MB/s]

# %%
# VIRAT_S_000200_03_000657_000899.activities.yml
# !gdown "https://drive.google.com/uc?id=1tTAnWLE5f9FhbWCe4vElR7gD9aK0jYin" -O test.activities.yml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tTAnWLE5f9FhbWCe4vElR7gD9aK0jYin
# To: /content/test.activities.yml
# 100% 14.3k/14.3k [00:00<00:00, 59.1MB/s]

# %%
# !ls -lh
# Out:
# total 31M
# drwxr-xr-x 1 root root 4.0K Jun 26 13:35 sample_data
# -rw-r--r-- 1 root root  14K Jun 27 18:21 test.activities.yml
# -rw-r--r-- 1 root root 8.2M Jun 27 18:21 test.geom.yml
# -rw-r--r-- 1 root root  10M Jun 27 18:21 test.mp4
# -rw-r--r-- 1 root root  12M Jun 27 18:21 test.regions.yml
# -rw-r--r-- 1 root root 2.7K Jun 27 18:21 test.types.yml

# %%
# get bounding boxes, classes and track ids for detections in all 300 frames of video
import yaml

file_path = 'test.geom.yml'
with open(file_path, 'r') as file:
    geom = yaml.safe_load(file)
file_path = 'test.types.yml'
with open(file_path, 'r') as file:
    types = yaml.safe_load(file)

# %% [markdown]
# ### Create Ground Truth DataFrame

# %% [markdown]
# AS pd.DataFrame </br>
# format: </br>
# {idx: geom_id0, </br>
# track_id: geom_id1, </br>
# label: types_cset3-key_on_id1, </br>
# conf: types_cset3-value_on_id1, </br>
# frame: geom_ts0, </br>
# xmin: geom_g0.split(' ')[0], ymin: geom_g0.split(' ')[1], xmax: geom_g0.split(' ')[2], ymax: geom_g0.split(' ')[3]}

# %%
detections = []

# lists for populating dictionary then DataFrame
idx = []
track_id = []
labels = []
labels_ints = []
confs = []
frame = []
xmin, ymin, xmax, ymax = [], [], [], []

for i in geom:
  try:
    if i['geom']['ts0'] < 300:  # populates detections data from first 300 frames
      detections.append(i)
      idx.append(i['geom']['id0'])
      track_id.append(i['geom']['id1'])
      frame.append(i['geom']['ts0'])
      bb = i['geom']['g0'].split(' ')
      xmin.append(int(bb[0]))
      ymin.append(int(bb[1]))
      xmax.append(int(bb[2]))
      ymax.append(int(bb[3]))

      for j in types:
        try:
          if j['types']['id1'] == track_id[-1]:  # pulls labels and confidences (by track id --> 'id1') from types.yaml file
            label, conf = next(iter(j['types']['cset3'].items()))
            confs.append(conf)
            labels.append(label)
            # also save labels as ints for comparison with YOLOv8 Predictions later on
            if label == 'Person':
              labels_ints.append(0)
            elif label == 'Bike':
              labels_ints.append(1)
            elif label == 'Vehicle':
              labels_ints.append(2)
            else:
              labels_ints.append(-1)
        except:
          pass
  except:
    pass

print('idx: ', len(idx),
      'track_id: ', len(track_id),
      'label: ', len(labels),
      'conf: ', len(confs),
      'frame: ', len(frame))


gt = {'idx_gt': idx, 'track_id_gt': track_id, 'label_gt': labels,
      'label_as_int_gt': labels_ints, 'conf_gt': confs, 'frame_gt': frame,
      'xmin_gt': xmin, 'ymin_gt': ymin, 'xmax_gt': xmax, 'ymax_gt': ymax}
df_gt = pd.DataFrame(gt)
df_gt
# Out:
# idx:  3406 track_id:  3406 label:  3406 conf:  3406 frame:  3406
#       idx_gt  track_id_gt label_gt  label_as_int_gt  conf_gt  frame_gt  \
# 0          0            1  Vehicle                2      1.0         0
# 1          1            1  Vehicle                2      1.0         1
# 2          2            1  Vehicle                2      1.0         2
# 3          3            1  Vehicle                2      1.0         3
# 4          4            1  Vehicle                2      1.0         4
# ...      ...          ...      ...              ...      ...       ...
# 3401   73049         5030     Door               -1      1.0       295
# 3402   73050         5030     Door               -1      1.0       296
# 3403   73051         5030     Door               -1      1.0       297
# 3404   73052         5030     Door               -1      1.0       298
# 3405   73053         5030     Door               -1      1.0       299
#
#       xmin_gt  ymin_gt  xmax_gt  ymax_gt
# 0         946      327     1010      360
# 1         945      326     1009      359
# 2         945      326     1009      359
# 3         945      326     1009      359
# 4         945      326     1009      359
# ...       ...      ...      ...      ...
# 3401       72      423       95      487
# 3402       72      423       95      487
# 3403       72      423       95      487
# 3404       72      423       95      487
# 3405       72      423       95      487
#
# [3406 rows x 10 columns]

# %% [markdown]
# ## Let's drop all detections besides Cars, People, and Bikes

# %%
df_gt = df_gt[df_gt['label_as_int_gt'] != -1]
df_gt.groupby('label_as_int_gt').count()
# Out:
#                  idx_gt  track_id_gt  label_gt  conf_gt  frame_gt  xmin_gt  \
# label_as_int_gt
# 0                   900          900       900      900       900      900
# 2                  1306         1306      1306     1306      1306     1306
#
#                  ymin_gt  xmax_gt  ymax_gt
# label_as_int_gt
# 0                    900      900      900
# 2                   1306     1306     1306

# %%
df_gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2206 entries, 0 to 2205
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idx_gt           2206 non-null   int64
#  1   track_id_gt      2206 non-null   int64
#  2   label_gt         2206 non-null   object
#  3   label_as_int_gt  2206 non-null   int64
#  4   conf_gt          2206 non-null   float64
#  5   frame_gt         2206 non-null   int64
#  6   xmin_gt          2206 non-null   int64
#  7   ymin_gt          2206 non-null   int64
#  8   xmax_gt          2206 non-null   int64
#  9   ymax_gt          2206 non-null   int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 189.6+ KB

# %% [markdown]
# ## 3. Get Predictions
# - get inference from YOLOv8 with ByteTracker on this test clip
# - store predictions in Pandas DataFrame 'preddf'

# %% [markdown]
# Install YOLOv8

# %%
# !pip -q install ultralytics
# !pip -q install lap
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.4/612.4 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lap (setup.py) ... done

# %%
from ultralytics import YOLO
import lap

model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 78.9MB/s]

# %%
results = model.track(source='/content/test.mp4', conf=0.12, iou=0.5,
                      device=0, save_txt=True, imgsz=1280, classes=[0,1,2],
                      tracker="bytetrack.yaml", stream=True)
list_results = list(results)
# Out:
# video 1/1 (1/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 106.0ms
# video 1/1 (2/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.5ms
# video 1/1 (3/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (4/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 14.7ms
# video 1/1 (5/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (6/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (7/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (8/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (9/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 15.5ms
# video 1/1 (10/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (11/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (12/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (13/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (14/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (15/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (16/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (17/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (18/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (19/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.3ms
# video 1/1 (20/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.4ms
# video 1/1 (21/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (22/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (23/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 15.5ms
# video 1/1 (24/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (25/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 15.5ms
# video 1/1 (26/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (27/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.6ms
# video 1/1 (28/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (29/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (30/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (31/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (32/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (33/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (34/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (35/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (36/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (37/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (38/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (39/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (40/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (41/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (42/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.2ms
# video 1/1 (43/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (44/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (45/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 13.1ms
# video 1/1 (46/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.8ms
# video 1/1 (47/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.8ms
# video 1/1 (48/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.8ms
# video 1/1 (49/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.7ms
# video 1/1 (50/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.8ms
# video 1/1 (51/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.8ms
# video 1/1 (52/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.8ms
# video 1/1 (53/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.1ms
# video 1/1 (54/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.2ms
# video 1/1 (55/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.1ms
# video 1/1 (56/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.1ms
# video 1/1 (57/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.1ms
# video 1/1 (58/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.1ms
# video 1/1 (59/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.1ms
# video 1/1 (60/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (61/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (62/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (63/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (64/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (65/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (66/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (67/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (68/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.9ms
# video 1/1 (69/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (70/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (71/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 15.0ms
# video 1/1 (72/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (73/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (74/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (75/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 11.4ms
# video 1/1 (76/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.9ms
# video 1/1 (77/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.8ms
# video 1/1 (78/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (79/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.9ms
# video 1/1 (80/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.8ms
# video 1/1 (81/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.6ms
# video 1/1 (82/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.6ms
# video 1/1 (83/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (84/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (85/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (86/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (87/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.6ms
# video 1/1 (88/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (89/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.0ms
# video 1/1 (90/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.0ms
# video 1/1 (91/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (92/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (93/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (94/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.0ms
# video 1/1 (95/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.1ms
# video 1/1 (96/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 10.0ms
# video 1/1 (97/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.9ms
# video 1/1 (98/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.9ms
# video 1/1 (99/300) /content/test.mp4: 736x1280 3 persons, 5 cars, 9.9ms
# video 1/1 (100/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (101/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (102/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (103/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (104/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (105/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (106/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (107/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (108/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (109/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (110/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (111/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (112/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (113/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (114/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (115/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (116/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (117/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.1ms
# video 1/1 (118/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (119/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (120/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (121/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (122/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (123/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (124/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (125/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.2ms
# video 1/1 (126/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.4ms
# video 1/1 (127/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (128/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (129/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (130/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (131/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (132/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (133/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (134/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (135/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (136/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (137/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (138/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (139/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (140/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (141/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (142/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (143/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (144/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (145/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.1ms
# video 1/1 (146/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (147/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (148/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (149/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.1ms
# video 1/1 (150/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 12.2ms
# video 1/1 (151/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (152/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (153/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (154/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (155/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (156/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (157/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (158/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (159/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (160/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (161/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.8ms
# video 1/1 (162/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (163/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (164/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (165/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (166/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (167/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (168/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (169/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (170/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (171/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (172/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (173/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (174/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (175/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (176/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (177/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (178/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (179/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (180/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (181/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (182/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (183/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (184/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (185/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (186/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (187/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (188/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (189/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (190/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (191/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (192/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (193/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (194/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (195/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (196/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (197/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (198/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (199/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (200/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (201/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.9ms
# video 1/1 (202/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (203/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (204/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (205/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (206/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (207/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (208/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (209/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (210/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.3ms
# video 1/1 (211/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (212/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (213/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (214/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (215/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (216/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (217/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (218/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (219/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (220/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (221/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (222/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (223/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.1ms
# video 1/1 (224/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (225/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (226/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (227/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (228/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (229/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.6ms
# video 1/1 (230/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (231/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (232/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (233/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (234/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (235/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (236/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (237/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (238/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (239/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.5ms
# video 1/1 (240/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.7ms
# video 1/1 (241/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (242/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (243/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (244/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (245/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (246/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (247/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (248/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (249/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (250/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (251/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.0ms
# video 1/1 (252/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (253/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (254/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (255/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (256/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (257/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (258/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (259/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (260/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.9ms
# video 1/1 (261/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (262/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (263/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (264/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (265/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (266/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (267/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (268/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (269/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (270/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (271/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (272/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (273/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 11.7ms
# video 1/1 (274/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (275/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (276/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (277/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (278/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.5ms
# video 1/1 (279/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (280/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.2ms
# video 1/1 (281/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (282/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (283/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (284/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.4ms
# video 1/1 (285/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (286/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (287/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (288/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (289/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# video 1/1 (290/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (291/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (292/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (293/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (294/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (295/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (296/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (297/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (298/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.3ms
# video 1/1 (299/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 10.7ms
# video 1/1 (300/300) /content/test.mp4: 736x1280 3 persons, 4 cars, 9.9ms
# Speed: 5.0ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs/detect/track
# 300 labels saved to runs/detect/track/labels

# %% [markdown]
# With `save_txt = True`, .txt files are in format `class_label xmid_ratio ymid_ratio width height track_id`

# %%
# frame 1 detections as .txt file(s)
# !cat runs/detect/track/labels/test_1.txt
# Out:
# 2 0.137419 0.553092 0.0945308 0.0548357 1
# 2 0.763876 0.478838 0.0469688 0.0366087 2
# 2 0.123751 0.511463 0.0826546 0.044233 3
# 2 0.567661 0.733765 0.111929 0.0792986 4
# 0 0.232489 0.761387 0.019395 0.080564 5
# 0 0.581185 0.575837 0.0138645 0.05707 6
# 2 0.751597 0.962718 0.090546 0.0741219 7
# 0 0.909582 0.944357 0.0208885 0.095949 8

# %% [markdown]
# A better way:</br>
# ultralytics.yolo.engine.results.Boxes attribute formats:
# - Boxes.data use [xmin, ymin, xmax, ymax, track_id, conf, class]

# %%
list_results[0].boxes.data
# Out:
# tensor([[1.1540e+02, 3.7849e+02, 2.3640e+02, 4.1797e+02, 1.0000e+00, 8.8784e-01, 2.0000e+00],
#         [9.4770e+02, 3.3158e+02, 1.0078e+03, 3.5794e+02, 2.0000e+00, 8.5510e-01, 2.0000e+00],
#         [1.0550e+02, 3.5233e+02, 2.1130e+02, 3.8418e+02, 3.0000e+00, 8.5349e-01, 2.0000e+00],
#         [6.5497e+02, 4.9976e+02, 7.9824e+02, 5.5686e+02, 4.0000e+00, 8.5208e-01, 2.0000e+00],
#         [2.8517e+02, 5.1920e+02, 3.1000e+02, 5.7720e+02, 5.0000e+00, 8.3465e-01, 0.0000e+00],
#         [7.3504e+02, 3.9406e+02, 7.5279e+02, 4.3515e+02, 6.0000e+00, 7.6037e-01, 0.0000e+00],
#         [9.0410e+02, 6.6647e+02, 1.0200e+03, 7.1984e+02, 7.0000e+00, 7.5590e-01, 2.0000e+00],
#         [1.1509e+03, 6.4540e+02, 1.1776e+03, 7.1448e+02, 8.0000e+00, 6.6577e-01, 0.0000e+00]])

# %% [markdown]
# ### Create DataFrame for predictions

# %%
len(list_results[0].boxes.data)
# Out:
# 8

# %%
# Create dictionary of predictions `df_pred

track_id = []
label = []
conf = []
frame = []
xmin, ymin, xmax, ymax = [], [], [], []

for i in range(len(list_results)):  # loop through all frames
  for j in range(len(list_results[i].boxes.data)):  # loop through all detections per frame
    bb = [torch.round(k) for k in iter(list_results[i].boxes.data[j])]  # enumerate data per detection: [xmin, ymin, xmax, ymax, track_id, conf, class]
    xmin.append(int(bb[0]))
    ymin.append(int(bb[1]))
    xmax.append(int(bb[2]))
    ymax.append(int(bb[3]))
    track_id.append(int(bb[4]))
    conf.append(int(bb[5]))
    label.append(int(bb[6]))
    frame.append(i)  # frames in gt start from 0

pred = {'track_id_pred': track_id, 'label_pred': label, 'conf_pred': conf, 'frame_pred': frame, 'xmin_pred': xmin, 'ymin_pred': ymin, 'xmax_pred': xmax, 'ymax_pred': ymax}

df_pred = pd.DataFrame(pred)
df_pred.head()
# Out:
#    track_id_pred  label_pred  conf_pred  frame_pred  xmin_pred  ymin_pred  \
# 0              1           2          1           0        115        378
# 1              2           2          1           0        948        332
# 2              3           2          1           0        106        352
# 3              4           2          1           0        655        500
# 4              5           0          1           0        285        519
#
#    xmax_pred  ymax_pred
# 0        236        418
# 1       1008        358
# 2        211        384
# 3        798        557
# 4        310        577

# %%
df_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2181 entries, 0 to 2180
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   track_id_pred  2181 non-null   int64
#  1   label_pred     2181 non-null   int64
#  2   conf_pred      2181 non-null   int64
#  3   frame_pred     2181 non-null   int64
#  4   xmin_pred      2181 non-null   int64
#  5   ymin_pred      2181 non-null   int64
#  6   xmax_pred      2181 non-null   int64
#  7   ymax_pred      2181 non-null   int64
# dtypes: int64(8)
# memory usage: 136.4 KB

# %% [markdown]
# ## Compare/Contrast dataframes

# %% [markdown]
# How many track_ids?

# %%
# ground truth
df_gt.groupby('track_id_gt').count()
# Out:
#              idx_gt  label_gt  label_as_int_gt  conf_gt  frame_gt  xmin_gt  \
# track_id_gt
# 1               300       300              300      300       300      300
# 2               300       300              300      300       300      300
# 3               300       300              300      300       300      300
# 4               300       300              300      300       300      300
# 5               106       106              106      106       106      106
# 33              300       300              300      300       300      300
# 34              300       300              300      300       300      300
# 35              300       300              300      300       300      300
#
#              ymin_gt  xmax_gt  ymax_gt
# track_id_gt
# 1                300      300      300
# 2                300      300      300
# 3                300      300      300
# 4                300      300      300
# 5                106      106      106
# 33               300      300      300
# 34               300      300      300
# 35               300      300      300

# %%
# predicted
df_pred.groupby('track_id_pred').count()
# Out:
#                label_pred  conf_pred  frame_pred  xmin_pred  ymin_pred  \
# track_id_pred
# 1                     300        300         300        300        300
# 2                     300        300         300        300        300
# 3                     300        300         300        300        300
# 4                     300        300         300        300        300
# 5                     300        300         300        300        300
# 6                     300        300         300        300        300
# 7                      81         81          81         81         81
# 8                     300        300         300        300        300
#
#                xmax_pred  ymax_pred
# track_id_pred
# 1                    300        300
# 2                    300        300
# 3                    300        300
# 4                    300        300
# 5                    300        300
# 6                    300        300
# 7                     81         81
# 8                    300        300

# %% [markdown]
# ## Get IOU scores for each frame & object of video

# %%
def get_iou(boxA, boxB):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.

    Parameters:
    boxA -- [xmin, ymin, xmax, ymax] of box A
    boxB -- [xmin, ymin, xmax, ymax] of box B

    Returns:
    iou   -- Intersection over Union
    """
    # determine the (x, y)-coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)

    # compute the area of both the prediction and ground-truth rectangles
    boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
    boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)

    # compute the intersection over union by taking the intersection area and dividing it by the sum of prediction + ground-truth areas - the intersection area
    iou = interArea / float(boxAArea + boxBArea - interArea)

    # return the intersection over union value
    return iou

# %%
# Create a cross join dataframe
df_gt['key'] = 1
df_pred['key'] = 1
df_cross = pd.merge(df_gt, df_pred, left_on=['key', 'frame_gt'], right_on=['key', 'frame_pred']).drop("key", axis=1)
# Out:
# <ipython-input-26-5e785a50da87>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gt['key'] = 1

# %%
df_cross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16090 entries, 0 to 16089
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idx_gt           16090 non-null  int64
#  1   track_id_gt      16090 non-null  int64
#  2   label_gt         16090 non-null  object
#  3   label_as_int_gt  16090 non-null  int64
#  4   conf_gt          16090 non-null  float64
#  5   frame_gt         16090 non-null  int64
#  6   xmin_gt          16090 non-null  int64
#  7   ymin_gt          16090 non-null  int64
#  8   xmax_gt          16090 non-null  int64
#  9   ymax_gt          16090 non-null  int64
#  10  track_id_pred    16090 non-null  int64
#  11  label_pred       16090 non-null  int64
#  12  conf_pred        16090 non-null  int64
#  13  frame_pred       16090 non-null  int64
#  14  xmin_pred        16090 non-null  int64
#  15  ymin_pred        16090 non-null  int64
#  16  xmax_pred        16090 non-null  int64
#  17  ymax_pred        16090 non-null  int64
# dtypes: float64(1), int64(16), object(1)
# memory usage: 2.3+ MB

# %%
# %%time

# Calculate IOU for each pair
df_cross['iou'] = df_cross.apply(lambda row: get_iou(row[['xmin_gt', 'ymin_gt', 'xmax_gt', 'ymax_gt']], row[['xmin_pred', 'ymin_pred', 'xmax_pred', 'ymax_pred']]), axis=1)

# Find the pairs with maximum IOU for each ground truth bounding box
df_matched = df_cross.loc[df_cross.groupby(['idx_gt'])['iou'].idxmax()]
# Out:
# CPU times: user 14.5 s, sys: 67.3 ms, total: 14.6 s
# Wall time: 14.7 s

# %%
df_matched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2206 entries, 1 to 16089
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idx_gt           2206 non-null   int64
#  1   track_id_gt      2206 non-null   int64
#  2   label_gt         2206 non-null   object
#  3   label_as_int_gt  2206 non-null   int64
#  4   conf_gt          2206 non-null   float64
#  5   frame_gt         2206 non-null   int64
#  6   xmin_gt          2206 non-null   int64
#  7   ymin_gt          2206 non-null   int64
#  8   xmax_gt          2206 non-null   int64
#  9   ymax_gt          2206 non-null   int64
#  10  track_id_pred    2206 non-null   int64
#  11  label_pred       2206 non-null   int64
#  12  conf_pred        2206 non-null   int64
#  13  frame_pred       2206 non-null   int64
#  14  xmin_pred        2206 non-null   int64
#  15  ymin_pred        2206 non-null   int64
#  16  xmax_pred        2206 non-null   int64
#  17  ymax_pred        2206 non-null   int64
#  18  iou              2206 non-null   float64
# dtypes: float64(2), int64(16), object(1)
# memory usage: 344.7+ KB

# %%
# How many missed predictions? ie ground truth box exists but no prediction box was given
df_matched[df_matched['iou']<.01].count()
# Out:
# idx_gt             25
# track_id_gt        25
# label_gt           25
# label_as_int_gt    25
# conf_gt            25
# frame_gt           25
# xmin_gt            25
# ymin_gt            25
# xmax_gt            25
# ymax_gt            25
# track_id_pred      25
# label_pred         25
# conf_pred          25
# frame_pred         25
# xmin_pred          25
# ymin_pred          25
# xmax_pred          25
# ymax_pred          25
# iou                25
# dtype: int64

# %%
len(df_gt) - len(df_pred)
# Out:
# 25

# %%
df_matched[df_matched['iou']<.01]
# Out:
#       idx_gt  track_id_gt label_gt  label_as_int_gt  conf_gt  frame_gt  \
# 4124   29036            5  Vehicle                2      1.0        64
# 4180   29037            5  Vehicle                2      1.0        65
# 4236   29038            5  Vehicle                2      1.0        66
# 4292   29039            5  Vehicle                2      1.0        67
# 4348   29040            5  Vehicle                2      1.0        68
# 4404   29041            5  Vehicle                2      1.0        69
# 4460   29042            5  Vehicle                2      1.0        70
# 4900   29049            5  Vehicle                2      1.0        77
# 4956   29050            5  Vehicle                2      1.0        78
# 5012   29051            5  Vehicle                2      1.0        79
# 5068   29052            5  Vehicle                2      1.0        80
# 5124   29053            5  Vehicle                2      1.0        81
# 5180   29054            5  Vehicle                2      1.0        82
# 5236   29055            5  Vehicle                2      1.0        83
# 5292   29056            5  Vehicle                2      1.0        84
# 5348   29057            5  Vehicle                2      1.0        85
# 5404   29058            5  Vehicle                2      1.0        86
# 5460   29059            5  Vehicle                2      1.0        87
# 6220   29071            5  Vehicle                2      1.0        99
# 6276   29072            5  Vehicle                2      1.0       100
# 6332   29073            5  Vehicle                2      1.0       101
# 6388   29074            5  Vehicle                2      1.0       102
# 6444   29075            5  Vehicle                2      1.0       103
# 6500   29076            5  Vehicle                2      1.0       104
# 6556   29077            5  Vehicle                2      1.0       105
#
#       xmin_gt  ymin_gt  xmax_gt  ymax_gt  track_id_pred  label_pred  \
# 4124     1123      519     1203      579              1           2
# 4180     1126      517     1205      577              1           2
# 4236     1129      515     1207      575              1           2
# 4292     1132      514     1209      573              1           2
# 4348     1135      512     1211      571              1           2
# 4404     1138      510     1213      569              1           2
# 4460     1141      508     1216      567              1           2
# 4900     1161      495     1231      553              1           2
# 4956     1163      494     1233      551              1           2
# 5012     1165      493     1235      549              1           2
# 5068     1168      492     1237      547              1           2
# 5124     1170      491     1239      545              1           2
# 5180     1172      489     1241      544              1           2
# 5236     1174      488     1243      542              1           2
# 5292     1177      487     1245      540              1           2
# 5348     1179      486     1247      538              1           2
# 5404     1181      485     1249      536              1           2
# 5460     1184      484     1251      535              1           2
# 6220     1207      471     1260      512              1           2
# 6276     1209      471     1261      510              1           2
# 6332     1211      471     1262      509              1           2
# 6388     1213      471     1262      506              1           2
# 6444     1215      472     1262      504              1           2
# 6500     1218      473     1262      502              1           2
# 6556     1223      477     1268      506              1           2
#
#       conf_pred  frame_pred  xmin_pred  ymin_pred  xmax_pred  ymax_pred  iou
# 4124          1          64        115        379        236        418  0.0
# 4180          1          65        115        379        236        418  0.0
# 4236          1          66        115        378        236        418  0.0
# 4292          1          67        115        378        236        418  0.0
# 4348          1          68        115        378        237        418  0.0
# 4404          1          69        115        378        236        418  0.0
# 4460          1          70        114        378        236        418  0.0
# 4900          1          77        115        378        236        418  0.0
# 4956          1          78        116        378        236        418  0.0
# 5012          1          79        115        378        236        418  0.0
# 5068          1          80        116        378        236        418  0.0
# 5124          1          81        116        378        236        418  0.0
# 5180          1          82        116        378        236        418  0.0
# 5236          1          83        116        378        236        418  0.0
# 5292          1          84        116        378        236        418  0.0
# 5348          1          85        116        378        236        418  0.0
# 5404          1          86        115        378        236        418  0.0
# 5460          1          87        115        378        236        418  0.0
# 6220          1          99        116        378        236        418  0.0
# 6276          1         100        115        378        236        418  0.0
# 6332          1         101        116        378        236        418  0.0
# 6388          1         102        115        378        237        418  0.0
# 6444          1         103        115        378        236        418  0.0
# 6500          1         104        116        378        236        418  0.0
# 6556          1         105        116        378        236        418  0.0

# %%
df_matched
# Out:
#        idx_gt  track_id_gt label_gt  label_as_int_gt  conf_gt  frame_gt  \
# 1           0            1  Vehicle                2      1.0         0
# 65          1            1  Vehicle                2      1.0         1
# 129         2            1  Vehicle                2      1.0         2
# 193         3            1  Vehicle                2      1.0         3
# 257         4            1  Vehicle                2      1.0         4
# ...       ...          ...      ...              ...      ...       ...
# 15893   46534           35   Person                0      1.0       295
# 15942   46535           35   Person                0      1.0       296
# 15991   46536           35   Person                0      1.0       297
# 16040   46537           35   Person                0      1.0       298
# 16089   46538           35   Person                0      1.0       299
#
#        xmin_gt  ymin_gt  xmax_gt  ymax_gt  track_id_pred  label_pred  \
# 1          946      327     1010      360              2           2
# 65         945      326     1009      359              2           2
# 129        945      326     1009      359              2           2
# 193        945      326     1009      359              2           2
# 257        945      326     1009      359              2           2
# ...        ...      ...      ...      ...            ...         ...
# 15893     1192      575     1240      639              8           0
# 15942     1192      575     1240      639              8           0
# 15991     1192      575     1240      639              8           0
# 16040     1192      575     1240      639              8           0
# 16089     1192      575     1240      639              8           0
#
#        conf_pred  frame_pred  xmin_pred  ymin_pred  xmax_pred  ymax_pred  \
# 1              1           0        948        332       1008        358
# 65             1           1        947        331       1008        358
# 129            1           2        947        331       1008        358
# 193            1           3        948        331       1008        358
# 257            1           4        948        331       1008        358
# ...          ...         ...        ...        ...        ...        ...
# 15893          1         295       1201        578       1227        636
# 15942          1         296       1201        578       1227        635
# 15991          1         297       1201        578       1227        635
# 16040          1         298       1201        577       1227        635
# 16089          1         299       1201        577       1227        635
#
#             iou
# 1      0.745249
# 65     0.785520
# 129    0.785520
# 193    0.772851
# 257    0.772851
# ...         ...
# 15893  0.500157
# 15942  0.491680
# 15991  0.491680
# 16040  0.500157
# 16089  0.500157
#
# [2206 rows x 19 columns]

# %%
df_matched.describe()
# Out:
#              idx_gt  track_id_gt  label_as_int_gt  conf_gt     frame_gt  \
# count   2206.000000  2206.000000      2206.000000   2206.0  2206.000000
# mean   23867.247053    15.471442         1.184044      1.0   144.839075
# std    15723.507103    15.424598         0.983141      0.0    87.283254
# min        0.000000     1.000000         0.000000      1.0     0.000000
# 25%     7494.250000     2.000000         0.000000      1.0    68.250000
# 50%    21931.500000     4.000000         2.000000      1.0   142.000000
# 75%    39641.750000    34.000000         2.000000      1.0   221.000000
# max    46538.000000    35.000000         2.000000      1.0   299.000000
#
#            xmin_gt      ymin_gt      xmax_gt      ymax_gt  track_id_pred  \
# count  2206.000000  2206.000000  2206.000000  2206.000000    2206.000000
# mean    611.516319   440.395286   690.878513   491.404352       4.212149
# std     403.081605    96.108346   384.374472   109.153721       2.269258
# min     102.000000   326.000000   212.000000   359.000000       1.000000
# 25%     114.000000   349.000000   237.000000   386.000000       2.000000
# 50%     647.000000   389.000000   801.000000   434.000000       4.000000
# 75%     945.000000   516.000000  1009.000000   577.000000       6.000000
# max    1223.000000   659.000000  1268.000000   718.000000       8.000000
#
#         label_pred    conf_pred   frame_pred    xmin_pred    ymin_pred  \
# count  2206.000000  2206.000000  2206.000000  2206.000000  2206.000000
# mean      1.184044     0.966455   144.839075   603.762013   443.074343
# std       0.983141     0.180095    87.283254   402.774660    96.166437
# min       0.000000     0.000000     0.000000   105.000000   331.000000
# 25%       0.000000     1.000000    68.250000   116.000000   353.000000
# 50%       2.000000     1.000000   142.000000   655.000000   392.000000
# 75%       2.000000     1.000000   221.000000   948.000000   518.000000
# max       2.000000     1.000000   299.000000  1217.000000   666.000000
#
#          xmax_pred    ymax_pred          iou
# count  2206.000000  2206.000000  2206.000000
# mean    676.128740   488.421578     0.722826
# std     382.701641   109.008040     0.145140
# min     211.000000   358.000000     0.000000
# 25%     236.000000   384.000000     0.604839
# 50%     798.000000   431.000000     0.772851
# 75%    1008.000000   577.000000     0.834739
# max    1257.000000   720.000000     0.903763

# %% [markdown]
# ### IOU Scores averaged for all 300 frames
# - for all detections collectively
# - per object individually

# %%
print('average IOU for all detections across the 300 frames')
df_matched['iou'].mean()
# Out:
# average IOU for all detections across the 300 frames
# 0.7228258909968059

# %%
print('average IOU for each distinct object')
df_matched.groupby('track_id_gt')[['label_as_int_gt', 'iou']].mean()
# Out:
# average IOU for each distinct object
#              label_as_int_gt       iou
# track_id_gt
# 1                        2.0  0.771644
# 2                        2.0  0.830496
# 3                        2.0  0.883685
# 4                        2.0  0.831063
# 5                        2.0  0.597647
# 33                       0.0  0.587742
# 34                       0.0  0.596150
# 35                       0.0  0.603232

# %%
print('the People on average had the worst IOU scores')
print('the Vehicles did very well, \nexcept for the one vehicle which is moving and disappears behind tree branches. \nThe detection model missed the last 25 frames of \nground truth for this. \nPartial Occlusion appears to be an issue.')
# Out:
# the People on average had the worst IOU scores
# the Vehicles did very well,
# except for the one vehicle which is moving and disappears behind tree branches.
# The detection model missed the last 25 frames of
# ground truth for this.
# Partial Occlusion appears to be an issue.
